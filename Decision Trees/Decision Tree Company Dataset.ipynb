sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  \
# 0    Medium        138      73           11         276    120          0
# 1      High        111      48           16         260     83          1
# 2    Medium        113      35           10         269     80          2
# 3    Medium        117     100            4         466     97          2
# 4       Low        141      64            3         340    128          0
# ..      ...        ...     ...          ...         ...    ...        ...
# 395    High        138     108           17         203    128          1
# 396  Medium        139      23            3          37    120          2
# 397  Medium        162      26           12         368    159          2
# 398  Medium        100      79            7         284     95          0
# 399  Medium        134      37            0          27    120          1
#
#      Age  Education  Urban  US
# 0     42         17      1   1
# 1     65         10      1   1
# 2     59         12      1   1
# 3     55         14      1   1
# 4     38         13      1   0
# ..   ...        ...    ...  ..
# 395   33         14      1   1
# 396   55         11      0   1
# 397   40         18      1   1
# 398   50         12      1   1
# 399   49         16      1   1
#
# [400 rows x 11 columns]

# %%
#data=data.iloc[:,0:-1]

# %%
data.Sales.unique()
# Out:
# ['Medium', 'High', 'Low']
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.metrics import classification_report

# %%
x=data.iloc[:,1:]
y=data['Sales']

# %%
x
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120          0   42
# 1          111      48           16         260     83          1   65
# 2          113      35           10         269     80          2   59
# 3          117     100            4         466     97          2   55
# 4          141      64            3         340    128          0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128          1   33
# 396        139      23            3          37    120          2   55
# 397        162      26           12         368    159          2   40
# 398        100      79            7         284     95          0   50
# 399        134      37            0          27    120          1   49
#
#      Education  Urban  US
# 0           17      1   1
# 1           10      1   1
# 2           12      1   1
# 3           14      1   1
# 4           13      1   0
# ..         ...    ...  ..
# 395         14      1   1
# 396         11      0   1
# 397         18      1   1
# 398         12      1   1
# 399         16      1   1
#
# [400 rows x 10 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size =0.33,random_state=10)

# %% [markdown]
# Criterion according to "Entropy"

# %%
model =DecisionTreeClassifier(criterion='entropy',max_depth=3)
model.fit(x_train,y_train)
y_pred =model.predict(x_test)

# %%
from sklearn import tree
tree.plot_tree(model)
# Out:
# [Text(167.4, 190.26, 'X[5] <= 0.5\nentropy = 1.326\nsamples = 268\nvalue = [33, 74, 161]'),
#  Text(83.7, 135.9, 'X[4] <= 93.0\nentropy = 1.029\nsamples = 65\nvalue = [1, 42, 22]'),
#  Text(41.85, 81.53999999999999, 'X[1] <= 32.5\nentropy = 0.817\nsamples = 12\nvalue = [1, 1, 10]'),
#  Text(20.925, 27.180000000000007, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(62.775000000000006, 27.180000000000007, 'entropy = 0.439\nsamples = 11\nvalue = [1, 0, 10]'),
#  Text(125.55000000000001, 81.53999999999999, 'X[4] <= 136.5\nentropy = 0.772\nsamples = 53\nvalue = [0, 41, 12]'),
#  Text(104.625, 27.180000000000007, 'entropy = 0.881\nsamples = 40\nvalue = [0, 28, 12]'),
#  Text(146.475, 27.180000000000007, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13, 0]'),
#  Text(251.10000000000002, 135.9, 'X[5] <= 1.5\nentropy = 1.214\nsamples = 203\nvalue = [32, 32, 139]'),
#  Text(209.25, 81.53999999999999, 'X[4] <= 121.5\nentropy = 1.178\nsamples = 57\nvalue = [25, 2, 30]'),
#  Text(188.32500000000002, 27.180000000000007, 'entropy = 0.869\nsamples = 31\nvalue = [22, 0, 9]'),
#  Text(230.175, 27.180000000000007, 'entropy = 0.893\nsamples = 26\nvalue = [3, 2, 21]'),
#  Text(292.95, 81.53999999999999, 'X[2] <= 6.5\nentropy = 0.994\nsamples = 146\nvalue = [7, 30, 109]'),
#  Text(272.02500000000003, 27.180000000000007, 'entropy = 1.012\nsamples = 80\nvalue = [1, 27, 52]'),
#  Text(313.875, 27.180000000000007, 'entropy = 0.7\nsamples = 66\nvalue = [6, 3, 57]')]

# %%
fn =['CompPrice', 'Income', 'Advertising', 'Population', 'Price',
       'ShelveLoc', 'Age', 'Education', 'Urban', 'US']
cn=['Medium', 'High', 'Low']
fig,axes =plt.subplots(nrows=1,ncols=1,figsize =(4,4),dpi =300)
tree.plot_tree(model,feature_names=fn,
               class_names=cn,
               filled= True)
# Out:
# [Text(465.0, 792.75, 'ShelveLoc <= 0.5\nentropy = 1.326\nsamples = 268\nvalue = [33, 74, 161]\nclass = Low'),
#  Text(232.5, 566.25, 'Price <= 93.0\nentropy = 1.029\nsamples = 65\nvalue = [1, 42, 22]\nclass = High'),
#  Text(116.25, 339.75, 'Income <= 32.5\nentropy = 0.817\nsamples = 12\nvalue = [1, 1, 10]\nclass = Low'),
#  Text(58.125, 113.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = High'),
#  Text(174.375, 113.25, 'entropy = 0.439\nsamples = 11\nvalue = [1, 0, 10]\nclass = Low'),
#  Text(348.75, 339.75, 'Price <= 136.5\nentropy = 0.772\nsamples = 53\nvalue = [0, 41, 12]\nclass = High'),
#  Text(290.625, 113.25, 'entropy = 0.881\nsamples = 40\nvalue = [0, 28, 12]\nclass = High'),
#  Text(406.875, 113.25, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13, 0]\nclass = High'),
#  Text(697.5, 566.25, 'ShelveLoc <= 1.5\nentropy = 1.214\nsamples = 203\nvalue = [32, 32, 139]\nclass = Low'),
#  Text(581.25, 339.75, 'Price <= 121.5\nentropy = 1.178\nsamples = 57\nvalue = [25, 2, 30]\nclass = Low'),
#  Text(523.125, 113.25, 'entropy = 0.869\nsamples = 31\nvalue = [22, 0, 9]\nclass = Medium'),
#  Text(639.375, 113.25, 'entropy = 0.893\nsamples = 26\nvalue = [3, 2, 21]\nclass = Low'),
#  Text(813.75, 339.75, 'Advertising <= 6.5\nentropy = 0.994\nsamples = 146\nvalue = [7, 30, 109]\nclass = Low'),
#  Text(755.625, 113.25, 'entropy = 1.012\nsamples = 80\nvalue = [1, 27, 52]\nclass = Low'),
#  Text(871.875, 113.25, 'entropy = 0.7\nsamples = 66\nvalue = [6, 3, 57]\nclass = Low')]

# %%
y_pred
# Out:
# array(['Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Low', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'High', 'Medium', 'Medium',
#        'Low', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Low',
#        'Medium', 'Medium', 'Low', 'Medium', 'Low', 'Medium', 'Medium',
#        'Medium', 'Low', 'High', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'High', 'Medium', 'Medium', 'Medium', 'High', 'Low',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Low', 'Medium', 'Low', 'Medium', 'Medium',
#        'High', 'Medium', 'Medium', 'Medium', 'High', 'Medium', 'Low',
#        'Low', 'Medium', 'Low', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Low', 'Low', 'Medium', 'Low', 'Medium', 'Low',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Low', 'Medium',
#        'Low', 'Medium', 'Medium', 'Medium', 'Low', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Low',
#        'Low', 'Low', 'Low', 'High', 'Medium', 'Medium', 'Low', 'Medium',
#        'Medium', 'Medium', 'High', 'High', 'Medium', 'Low', 'Medium',
#        'Medium', 'High', 'Medium', 'Medium', 'Medium', 'High', 'Low'],
#       dtype=object)

# %%
accuracy =accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.5984848484848485

# %%
count_misclassified =(y_test != y_pred).sum()
count_misclassified
# Out:
# 53

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.22      0.28        18
#            1       0.42      0.39      0.41        28
#            2       0.67      0.74      0.71        86
#
#     accuracy                           0.60       132
#    macro avg       0.49      0.45      0.46       132
# weighted avg       0.58      0.60      0.58       132

# %% [markdown]
# according to the criterion= gini

# %%
model1=DecisionTreeClassifier(criterion='gini',max_depth=3)
model1.fit(x_train,y_train)
y_pred1=model1.predict(x_test)

# %%
tree.plot_tree(model1)
# Out:
# [Text(167.4, 190.26, 'X[5] <= 0.5\ngini = 0.548\nsamples = 268\nvalue = [33, 74, 161]'),
#  Text(83.7, 135.9, 'X[4] <= 93.0\ngini = 0.468\nsamples = 65\nvalue = [1, 42, 22]'),
#  Text(41.85, 81.53999999999999, 'X[3] <= 69.5\ngini = 0.292\nsamples = 12\nvalue = [1, 1, 10]'),
#  Text(20.925, 27.180000000000007, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(62.775000000000006, 27.180000000000007, 'gini = 0.165\nsamples = 11\nvalue = [0, 1, 10]'),
#  Text(125.55000000000001, 81.53999999999999, 'X[0] <= 151.0\ngini = 0.35\nsamples = 53\nvalue = [0, 41, 12]'),
#  Text(104.625, 27.180000000000007, 'gini = 0.315\nsamples = 51\nvalue = [0, 41, 10]'),
#  Text(146.475, 27.180000000000007, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(251.10000000000002, 135.9, 'X[5] <= 1.5\ngini = 0.481\nsamples = 203\nvalue = [32, 32, 139]'),
#  Text(209.25, 81.53999999999999, 'X[4] <= 107.5\ngini = 0.529\nsamples = 57\nvalue = [25, 2, 30]'),
#  Text(188.32500000000002, 27.180000000000007, 'gini = 0.255\nsamples = 20\nvalue = [17, 0, 3]'),
#  Text(230.175, 27.180000000000007, 'gini = 0.418\nsamples = 37\nvalue = [8, 2, 27]'),
#  Text(292.95, 81.53999999999999, 'X[2] <= 1.5\ngini = 0.398\nsamples = 146\nvalue = [7, 30, 109]'),
#  Text(272.02500000000003, 27.180000000000007, 'gini = 0.493\nsamples = 60\nvalue = [1, 23, 36]'),
#  Text(313.875, 27.180000000000007, 'gini = 0.268\nsamples = 86\nvalue = [6, 7, 73]')]

# %%
fn =['CompPrice', 'Income', 'Advertising', 'Population', 'Price',
       'ShelveLoc', 'Age', 'Education', 'Urban', 'US']
cn=['Medium', 'High', 'Low']
fig,axes =plt.subplots(nrows=1,ncols=1,figsize =(4,4),dpi =300)
tree.plot_tree(model1,feature_names=fn,
               class_names=cn,
               filled= True)
# Out:
# [Text(465.0, 792.75, 'ShelveLoc <= 0.5\ngini = 0.548\nsamples = 268\nvalue = [33, 74, 161]\nclass = Low'),
#  Text(232.5, 566.25, 'Price <= 93.0\ngini = 0.468\nsamples = 65\nvalue = [1, 42, 22]\nclass = High'),
#  Text(116.25, 339.75, 'Population <= 69.5\ngini = 0.292\nsamples = 12\nvalue = [1, 1, 10]\nclass = Low'),
#  Text(58.125, 113.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = Medium'),
#  Text(174.375, 113.25, 'gini = 0.165\nsamples = 11\nvalue = [0, 1, 10]\nclass = Low'),
#  Text(348.75, 339.75, 'CompPrice <= 151.0\ngini = 0.35\nsamples = 53\nvalue = [0, 41, 12]\nclass = High'),
#  Text(290.625, 113.25, 'gini = 0.315\nsamples = 51\nvalue = [0, 41, 10]\nclass = High'),
#  Text(406.875, 113.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = Low'),
#  Text(697.5, 566.25, 'ShelveLoc <= 1.5\ngini = 0.481\nsamples = 203\nvalue = [32, 32, 139]\nclass = Low'),
#  Text(581.25, 339.75, 'Price <= 107.5\ngini = 0.529\nsamples = 57\nvalue = [25, 2, 30]\nclass = Low'),
#  Text(523.125, 113.25, 'gini = 0.255\nsamples = 20\nvalue = [17, 0, 3]\nclass = Medium'),
#  Text(639.375, 113.25, 'gini = 0.418\nsamples = 37\nvalue = [8, 2, 27]\nclass = Low'),
#  Text(813.75, 339.75, 'Advertising <= 1.5\ngini = 0.398\nsamples = 146\nvalue = [7, 30, 109]\nclass = Low'),
#  Text(755.625, 113.25, 'gini = 0.493\nsamples = 60\nvalue = [1, 23, 36]\nclass = Low'),
#  Text(871.875, 113.25, 'gini = 0.268\nsamples = 86\nvalue = [6, 7, 73]\nclass = Low')]

# %%
y_pred1
# Out:
# array(['Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Low', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Low', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Low', 'Medium', 'Medium', 'Low', 'Medium', 'Low', 'Medium',
#        'Medium', 'Medium', 'Low', 'High', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'High', 'Medium', 'Medium', 'Medium', 'High',
#        'Low', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Low', 'Medium', 'Medium',
#        'High', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Low',
#        'Low', 'Medium', 'Low', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Low', 'Low', 'Medium', 'Medium', 'Medium',
#        'Low', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Low', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Low', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Low',
#        'Low', 'Low', 'Low', 'High', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'High', 'Medium', 'Low',
#        'Medium', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Low'], dtype=object)

# %%
accuracy =accuracy_score(y_test,y_pred1)
accuracy
# Out:
# 0.6666666666666666

# %%
count_misclassified =(y_test != y_pred1).sum()
count_misclassified
# Out:
# 44

# %%
pd.crosstab(y_test,y_pred1)
# Out:
# col_0   High  Low  Medium
# Sales
# Low        0   11      17
# Medium     2   11      73
# High       4    0      14

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.67      0.22      0.33        18
#          Low       0.50      0.39      0.44        28
#       Medium       0.70      0.85      0.77        86
#
#     accuracy                           0.67       132
#    macro avg       0.62      0.49      0.51       132
# weighted avg       0.65      0.67      0.64       132

# %%
data['Sales'] =encoder1.fit_transform(data['Sales'])

# %%
data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0        2        138      73           11         276    120          0   42
# 1        0        111      48           16         260     83          1   65
# 2        2        113      35           10         269     80          2   59
# 3        2        117     100            4         466     97          2   55
# 4        1        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395      0        138     108           17         203    128          1   33
# 396      2        139      23            3          37    120          2   55
# 397      2        162      26           12         368    159          2   40
# 398      2        100      79            7         284     95          0   50
# 399      2        134      37            0          27    120          1   49
#
#      Education  Urban  US
# 0           17      1   1
# 1           10      1   1
# 2           12      1   1
# 3           14      1   1
# 4           13      1   0
# ..         ...    ...  ..
# 395         14      1   1
# 396         11      0   1
# 397         18      1   1
# 398         12      1   1
# 399         16      1   1
#
# [400 rows x 11 columns]

# %%
data =np.array(data)

# %%
x=data[:,1:]
y=data[:,0]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.33,random_state=10)

# %%
x_test
# Out:
# array([[106,  33,  20, ...,  12,   1,   1],
#        [132, 118,  12, ...,  14,   1,   1],
#        [133, 103,  14, ...,  17,   1,   1],
#        ...,
#        [108,  38,   0, ...,  14,   0,   0],
#        [131, 113,   0, ...,  14,   1,   0],
#        [125,  67,   0, ...,  11,   1,   0]], dtype=int64)

# %% [markdown]
# # Decision Tree In Auto Mode

# %%
from  sklearn.tree import DecisionTreeRegressor

# %%
rkmodel =DecisionTreeRegressor()
rkmodel.fit(x_train,y_train)
y_predrk =rkmodel.predict(x_test)

# %%
tree.plot_tree(rkmodel)
# Out:
# [Text(179.49426605504587, 209.6742857142857, 'X[5] <= 1.5\nmse = 0.496\nsamples = 268\nvalue = 1.478'),
#  Text(94.32247706422018, 194.14285714285714, 'X[4] <= 118.5\nmse = 0.594\nsamples = 122\nvalue = 1.213'),
#  Text(45.04954128440367, 178.61142857142858, 'X[5] <= 0.5\nmse = 0.729\nsamples = 59\nvalue = 0.983'),
#  Text(18.429357798165135, 163.07999999999998, 'X[6] <= 53.0\nmse = 0.307\nsamples = 30\nvalue = 1.4'),
#  Text(8.190825688073394, 147.54857142857142, 'X[4] <= 113.0\nmse = 0.109\nsamples = 8\nvalue = 1.875'),
#  Text(4.095412844036697, 132.01714285714286, 'mse = 0.0\nsamples = 7\nvalue = 2.0'),
#  Text(12.28623853211009, 132.01714285714286, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(28.66788990825688, 147.54857142857142, 'X[6] <= 77.0\nmse = 0.267\nsamples = 22\nvalue = 1.227'),
#  Text(20.477064220183486, 132.01714285714286, 'X[3] <= 49.0\nmse = 0.184\nsamples = 16\nvalue = 1.062'),
#  Text(16.381651376146788, 116.48571428571428, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(24.57247706422018, 116.48571428571428, 'X[1] <= 96.5\nmse = 0.116\nsamples = 15\nvalue = 1.133'),
#  Text(20.477064220183486, 100.9542857142857, 'mse = 0.0\nsamples = 12\nvalue = 1.0'),
#  Text(28.66788990825688, 100.9542857142857, 'X[7] <= 14.0\nmse = 0.222\nsamples = 3\nvalue = 1.667'),
#  Text(24.57247706422018, 85.42285714285714, 'mse = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(32.763302752293576, 85.42285714285714, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(36.85871559633027, 132.01714285714286, 'X[4] <= 93.0\nmse = 0.222\nsamples = 6\nvalue = 1.667'),
#  Text(32.763302752293576, 116.48571428571428, 'mse = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(40.95412844036697, 116.48571428571428, 'X[9] <= 0.5\nmse = 0.222\nsamples = 3\nvalue = 1.333'),
#  Text(36.85871559633027, 100.9542857142857, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(45.04954128440367, 100.9542857142857, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(71.6697247706422, 163.07999999999998, 'X[8] <= 0.5\nmse = 0.799\nsamples = 29\nvalue = 0.552'),
#  Text(61.43119266055046, 147.54857142857142, 'X[6] <= 51.5\nmse = 0.992\nsamples = 11\nvalue = 1.091'),
#  Text(53.24036697247706, 132.01714285714286, 'X[1] <= 54.0\nmse = 0.64\nsamples = 5\nvalue = 0.4'),
#  Text(49.14495412844036, 116.48571428571428, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(57.33577981651376, 116.48571428571428, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(69.62201834862385, 132.01714285714286, 'X[0] <= 131.0\nmse = 0.556\nsamples = 6\nvalue = 1.667'),
#  Text(65.52660550458715, 116.48571428571428, 'mse = 0.0\nsamples = 5\nvalue = 2.0'),
#  Text(73.71743119266054, 116.48571428571428, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(81.90825688073394, 147.54857142857142, 'X[6] <= 25.5\nmse = 0.395\nsamples = 18\nvalue = 0.222'),
#  Text(77.81284403669724, 132.01714285714286, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(86.00366972477063, 132.01714285714286, 'X[4] <= 108.5\nmse = 0.221\nsamples = 17\nvalue = 0.118'),
#  Text(81.90825688073394, 116.48571428571428, 'mse = 0.0\nsamples = 14\nvalue = 0.0'),
#  Text(90.09908256880733, 116.48571428571428, 'X[4] <= 111.0\nmse = 0.889\nsamples = 3\nvalue = 0.667'),
#  Text(86.00366972477063, 100.9542857142857, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(94.19449541284403, 100.9542857142857, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(143.5954128440367, 178.61142857142858, 'X[1] <= 56.0\nmse = 0.372\nsamples = 63\nvalue = 1.429'),
#  Text(114.67155963302751, 163.07999999999998, 'X[7] <= 16.5\nmse = 0.188\nsamples = 20\nvalue = 1.75'),
#  Text(106.48073394495412, 147.54857142857142, 'X[1] <= 29.0\nmse = 0.062\nsamples = 15\nvalue = 1.933'),
#  Text(102.38532110091742, 132.01714285714286, 'X[1] <= 24.5\nmse = 0.222\nsamples = 3\nvalue = 1.667'),
#  Text(98.28990825688072, 116.48571428571428, 'mse = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(106.48073394495412, 116.48571428571428, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(110.57614678899083, 132.01714285714286, 'mse = 0.0\nsamples = 12\nvalue = 2.0'),
#  Text(122.86238532110092, 147.54857142857142, 'X[2] <= 11.5\nmse = 0.16\nsamples = 5\nvalue = 1.2'),
#  Text(118.76697247706421, 132.01714285714286, 'mse = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(126.9577981651376, 132.01714285714286, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(172.51926605504588, 163.07999999999998, 'X[2] <= 12.0\nmse = 0.387\nsamples = 43\nvalue = 1.279'),
#  Text(148.45871559633028, 147.54857142857142, 'X[6] <= 28.5\nmse = 0.299\nsamples = 33\nvalue = 1.394'),
#  Text(135.148623853211, 132.01714285714286, 'X[4] <= 139.5\nmse = 0.16\nsamples = 5\nvalue = 0.8'),
#  Text(131.0532110091743, 116.48571428571428, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(139.2440366972477, 116.48571428571428, 'mse = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(161.76880733944952, 132.01714285714286, 'X[5] <= 0.5\nmse = 0.25\nsamples = 28\nvalue = 1.5'),
#  Text(147.43486238532108, 116.48571428571428, 'X[4] <= 125.0\nmse = 0.188\nsamples = 16\nvalue = 1.25'),
#  Text(139.2440366972477, 100.9542857142857, 'X[3] <= 11.5\nmse = 0.188\nsamples = 4\nvalue = 1.75'),
#  Text(135.148623853211, 85.42285714285714, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(143.3394495412844, 85.42285714285714, 'mse = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(155.62568807339449, 100.9542857142857, 'X[1] <= 114.0\nmse = 0.076\nsamples = 12\nvalue = 1.083'),
#  Text(151.53027522935778, 85.42285714285714, 'mse = 0.0\nsamples = 10\nvalue = 1.0'),
#  Text(159.7211009174312, 85.42285714285714, 'X[0] <= 140.0\nmse = 0.25\nsamples = 2\nvalue = 1.5'),
#  Text(155.62568807339449, 69.89142857142858, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(163.8165137614679, 69.89142857142858, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(176.10275229357796, 116.48571428571428, 'X[6] <= 75.5\nmse = 0.139\nsamples = 12\nvalue = 1.833'),
#  Text(172.00733944954126, 100.9542857142857, 'X[1] <= 107.0\nmse = 0.083\nsamples = 11\nvalue = 1.909'),
#  Text(167.9119266055046, 85.42285714285714, 'mse = 0.0\nsamples = 10\nvalue = 2.0'),
#  Text(176.10275229357796, 85.42285714285714, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(180.19816513761467, 100.9542857142857, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(196.57981651376144, 147.54857142857142, 'X[0] <= 123.0\nmse = 0.49\nsamples = 10\nvalue = 0.9'),
#  Text(188.38899082568807, 132.01714285714286, 'X[1] <= 92.5\nmse = 0.222\nsamples = 3\nvalue = 1.667'),
#  Text(184.29357798165137, 116.48571428571428, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(192.48440366972477, 116.48571428571428, 'mse = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(204.77064220183485, 132.01714285714286, 'X[4] <= 136.5\nmse = 0.245\nsamples = 7\nvalue = 0.571'),
#  Text(200.67522935779814, 116.48571428571428, 'mse = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(208.86605504587155, 116.48571428571428, 'mse = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(264.66605504587153, 194.14285714285714, 'X[3] <= 20.5\nmse = 0.306\nsamples = 146\nvalue = 1.699'),
#  Text(256.4752293577981, 178.61142857142858, 'X[4] <= 85.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(252.37981651376145, 163.07999999999998, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(260.57064220183486, 163.07999999999998, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(272.85688073394493, 178.61142857142858, 'X[3] <= 508.5\nmse = 0.287\nsamples = 144\nvalue = 1.715'),
#  Text(268.76146788990826, 163.07999999999998, 'X[2] <= 1.5\nmse = 0.268\nsamples = 143\nvalue = 1.727'),
#  Text(240.60550458715596, 147.54857142857142, 'X[4] <= 109.5\nmse = 0.275\nsamples = 59\nvalue = 1.593'),
#  Text(221.15229357798165, 132.01714285714286, 'X[3] <= 397.5\nmse = 0.186\nsamples = 25\nvalue = 1.88'),
#  Text(217.05688073394495, 116.48571428571428, 'mse = 0.0\nsamples = 20\nvalue = 2.0'),
#  Text(225.24770642201833, 116.48571428571428, 'X[6] <= 64.5\nmse = 0.64\nsamples = 5\nvalue = 1.4'),
#  Text(221.15229357798165, 100.9542857142857, 'X[0] <= 106.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(217.05688073394495, 85.42285714285714, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(225.24770642201833, 85.42285714285714, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(229.34311926605503, 100.9542857142857, 'mse = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(260.0587155963303, 132.01714285714286, 'X[0] <= 136.5\nmse = 0.236\nsamples = 34\nvalue = 1.382'),
#  Text(245.72477064220183, 116.48571428571428, 'X[7] <= 11.5\nmse = 0.16\nsamples = 20\nvalue = 1.2'),
#  Text(237.53394495412843, 100.9542857142857, 'X[4] <= 126.0\nmse = 0.188\nsamples = 4\nvalue = 1.75'),
#  Text(233.43853211009173, 85.42285714285714, 'mse = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(241.62935779816513, 85.42285714285714, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(253.9155963302752, 100.9542857142857, 'X[1] <= 99.5\nmse = 0.059\nsamples = 16\nvalue = 1.062'),
#  Text(249.8201834862385, 85.42285714285714, 'mse = 0.0\nsamples = 13\nvalue = 1.0'),
#  Text(258.01100917431194, 85.42285714285714, 'X[1] <= 106.5\nmse = 0.222\nsamples = 3\nvalue = 1.333'),
#  Text(253.9155963302752, 69.89142857142858, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(262.1064220183486, 69.89142857142858, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(274.3926605504587, 116.48571428571428, 'X[6] <= 67.5\nmse = 0.23\nsamples = 14\nvalue = 1.643'),
#  Text(270.297247706422, 100.9542857142857, 'X[4] <= 153.0\nmse = 0.149\nsamples = 11\nvalue = 1.818'),
#  Text(266.2018348623853, 85.42285714285714, 'mse = 0.0\nsamples = 8\nvalue = 2.0'),
#  Text(274.3926605504587, 85.42285714285714, 'X[6] <= 51.5\nmse = 0.222\nsamples = 3\nvalue = 1.333'),
#  Text(270.297247706422, 69.89142857142858, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(278.4880733944954, 69.89142857142858, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(278.4880733944954, 100.9542857142857, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(296.91743119266056, 147.54857142857142, 'X[0] <= 94.5\nmse = 0.242\nsamples = 84\nvalue = 1.821'),
#  Text(286.6788990825688, 132.01714285714286, 'X[7] <= 14.0\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(282.5834862385321, 116.48571428571428, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(290.7743119266055, 116.48571428571428, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(307.1559633027523, 132.01714285714286, 'X[3] <= 32.0\nmse = 0.198\nsamples = 82\nvalue = 1.854'),
#  Text(298.9651376146789, 116.48571428571428, 'X[1] <= 73.5\nmse = 0.688\nsamples = 4\nvalue = 1.25'),
#  Text(294.86972477064216, 100.9542857142857, 'mse = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(303.06055045871557, 100.9542857142857, 'X[2] <= 12.0\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(298.9651376146789, 85.42285714285714, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(307.1559633027523, 85.42285714285714, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(315.34678899082564, 116.48571428571428, 'X[1] <= 22.0\nmse = 0.153\nsamples = 78\nvalue = 1.885'),
#  Text(311.25137614678897, 100.9542857142857, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(319.4422018348624, 100.9542857142857, 'X[3] <= 499.5\nmse = 0.145\nsamples = 77\nvalue = 1.896'),
#  Text(315.34678899082564, 85.42285714285714, 'X[0] <= 143.5\nmse = 0.136\nsamples = 76\nvalue = 1.908'),
#  Text(304.08440366972474, 69.89142857142858, 'X[0] <= 100.0\nmse = 0.045\nsamples = 63\nvalue = 1.952'),
#  Text(293.845871559633, 54.359999999999985, 'X[1] <= 70.0\nmse = 0.25\nsamples = 2\nvalue = 1.5'),
#  Text(289.7504587155963, 38.82857142857142, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(297.9412844036697, 38.82857142857142, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(314.3229357798165, 54.359999999999985, 'X[3] <= 495.0\nmse = 0.032\nsamples = 61\nvalue = 1.967'),
#  Text(306.13211009174313, 38.82857142857142, 'X[2] <= 18.5\nmse = 0.017\nsamples = 58\nvalue = 1.983'),
#  Text(302.0366972477064, 23.29714285714286, 'mse = 0.0\nsamples = 52\nvalue = 2.0'),
#  Text(310.2275229357798, 23.29714285714286, 'X[4] <= 121.5\nmse = 0.139\nsamples = 6\nvalue = 1.833'),
#  Text(306.13211009174313, 7.765714285714267, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(314.3229357798165, 7.765714285714267, 'mse = 0.0\nsamples = 5\nvalue = 2.0'),
#  Text(322.5137614678899, 38.82857142857142, 'X[1] <= 43.0\nmse = 0.222\nsamples = 3\nvalue = 1.667'),
#  Text(318.4183486238532, 23.29714285714286, 'mse = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(326.6091743119266, 23.29714285714286, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(326.6091743119266, 69.89142857142858, 'X[4] <= 110.0\nmse = 0.521\nsamples = 13\nvalue = 1.692'),
#  Text(322.5137614678899, 54.359999999999985, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(330.7045871559633, 54.359999999999985, 'mse = 0.0\nsamples = 11\nvalue = 2.0'),
#  Text(323.53761467889905, 85.42285714285714, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(276.95229357798166, 163.07999999999998, 'mse = 0.0\nsamples = 1\nvalue = 0.0')]

# %%
fn =['CompPrice', 'Income', 'Advertising', 'Population', 'Price',
       'ShelveLoc', 'Age', 'Education', 'Urban', 'US']
cn=['Medium', 'High', 'Low']
fig,axes =plt.subplots(nrows=1,ncols=1,figsize =(4,4),dpi =300)
tree.plot_tree(rkmodel,feature_names=fn,
               class_names=cn,
               filled= True)
# Out:
# [Text(498.5951834862385, 873.6428571428571, 'ShelveLoc <= 1.5\nmse = 0.496\nsamples = 268\nvalue = 1.478'),
#  Text(262.0068807339449, 808.9285714285714, 'Price <= 118.5\nmse = 0.594\nsamples = 122\nvalue = 1.213'),
#  Text(125.13761467889907, 744.2142857142858, 'ShelveLoc <= 0.5\nmse = 0.729\nsamples = 59\nvalue = 0.983'),
#  Text(51.19266055045871, 679.5, 'Age <= 53.0\nmse = 0.307\nsamples = 30\nvalue = 1.4'),
#  Text(22.75229357798165, 614.7857142857143, 'Price <= 113.0\nmse = 0.109\nsamples = 8\nvalue = 1.875'),
#  Text(11.376146788990825, 550.0714285714287, 'mse = 0.0\nsamples = 7\nvalue = 2.0'),
#  Text(34.12844036697248, 550.0714285714287, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(79.63302752293578, 614.7857142857143, 'Age <= 77.0\nmse = 0.267\nsamples = 22\nvalue = 1.227'),
#  Text(56.88073394495412, 550.0714285714287, 'Population <= 49.0\nmse = 0.184\nsamples = 16\nvalue = 1.062'),
#  Text(45.5045871559633, 485.3571428571429, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(68.25688073394495, 485.3571428571429, 'Income <= 96.5\nmse = 0.116\nsamples = 15\nvalue = 1.133'),
#  Text(56.88073394495412, 420.64285714285717, 'mse = 0.0\nsamples = 12\nvalue = 1.0'),
#  Text(79.63302752293578, 420.64285714285717, 'Education <= 14.0\nmse = 0.222\nsamples = 3\nvalue = 1.667'),
#  Text(68.25688073394495, 355.92857142857144, 'mse = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(91.0091743119266, 355.92857142857144, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(102.38532110091742, 550.0714285714287, 'Price <= 93.0\nmse = 0.222\nsamples = 6\nvalue = 1.667'),
#  Text(91.0091743119266, 485.3571428571429, 'mse = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(113.76146788990825, 485.3571428571429, 'US <= 0.5\nmse = 0.222\nsamples = 3\nvalue = 1.333'),
#  Text(102.38532110091742, 420.64285714285717, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(125.13761467889907, 420.64285714285717, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(199.08256880733944, 679.5, 'Urban <= 0.5\nmse = 0.799\nsamples = 29\nvalue = 0.552'),
#  Text(170.64220183486236, 614.7857142857143, 'Age <= 51.5\nmse = 0.992\nsamples = 11\nvalue = 1.091'),
#  Text(147.88990825688072, 550.0714285714287, 'Income <= 54.0\nmse = 0.64\nsamples = 5\nvalue = 0.4'),
#  Text(136.5137614678899, 485.3571428571429, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(159.26605504587155, 485.3571428571429, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(193.39449541284404, 550.0714285714287, 'CompPrice <= 131.0\nmse = 0.556\nsamples = 6\nvalue = 1.667'),
#  Text(182.0183486238532, 485.3571428571429, 'mse = 0.0\nsamples = 5\nvalue = 2.0'),
#  Text(204.77064220183485, 485.3571428571429, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(227.5229357798165, 614.7857142857143, 'Age <= 25.5\nmse = 0.395\nsamples = 18\nvalue = 0.222'),
#  Text(216.14678899082568, 550.0714285714287, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(238.89908256880733, 550.0714285714287, 'Price <= 108.5\nmse = 0.221\nsamples = 17\nvalue = 0.118'),
#  Text(227.5229357798165, 485.3571428571429, 'mse = 0.0\nsamples = 14\nvalue = 0.0'),
#  Text(250.27522935779814, 485.3571428571429, 'Price <= 111.0\nmse = 0.889\nsamples = 3\nvalue = 0.667'),
#  Text(238.89908256880733, 420.64285714285717, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(261.65137614678895, 420.64285714285717, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(398.8761467889908, 744.2142857142858, 'Income <= 56.0\nmse = 0.372\nsamples = 63\nvalue = 1.429'),
#  Text(318.5321100917431, 679.5, 'Education <= 16.5\nmse = 0.188\nsamples = 20\nvalue = 1.75'),
#  Text(295.77981651376143, 614.7857142857143, 'Income <= 29.0\nmse = 0.062\nsamples = 15\nvalue = 1.933'),
#  Text(284.4036697247706, 550.0714285714287, 'Income <= 24.5\nmse = 0.222\nsamples = 3\nvalue = 1.667'),
#  Text(273.0275229357798, 485.3571428571429, 'mse = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(295.77981651376143, 485.3571428571429, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(307.1559633027523, 550.0714285714287, 'mse = 0.0\nsamples = 12\nvalue = 2.0'),
#  Text(341.2844036697247, 614.7857142857143, 'Advertising <= 11.5\nmse = 0.16\nsamples = 5\nvalue = 1.2'),
#  Text(329.9082568807339, 550.0714285714287, 'mse = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(352.6605504587156, 550.0714285714287, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(479.2201834862385, 679.5, 'Advertising <= 12.0\nmse = 0.387\nsamples = 43\nvalue = 1.279'),
#  Text(412.3853211009174, 614.7857142857143, 'Age <= 28.5\nmse = 0.299\nsamples = 33\nvalue = 1.394'),
#  Text(375.4128440366972, 550.0714285714287, 'Price <= 139.5\nmse = 0.16\nsamples = 5\nvalue = 0.8'),
#  Text(364.0366972477064, 485.3571428571429, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(386.7889908256881, 485.3571428571429, 'mse = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(449.3577981651376, 550.0714285714287, 'ShelveLoc <= 0.5\nmse = 0.25\nsamples = 28\nvalue = 1.5'),
#  Text(409.5412844036697, 485.3571428571429, 'Price <= 125.0\nmse = 0.188\nsamples = 16\nvalue = 1.25'),
#  Text(386.7889908256881, 420.64285714285717, 'Population <= 11.5\nmse = 0.188\nsamples = 4\nvalue = 1.75'),
#  Text(375.4128440366972, 355.92857142857144, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(398.1651376146789, 355.92857142857144, 'mse = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(432.29357798165137, 420.64285714285717, 'Income <= 114.0\nmse = 0.076\nsamples = 12\nvalue = 1.083'),
#  Text(420.9174311926605, 355.92857142857144, 'mse = 0.0\nsamples = 10\nvalue = 1.0'),
#  Text(443.6697247706422, 355.92857142857144, 'CompPrice <= 140.0\nmse = 0.25\nsamples = 2\nvalue = 1.5'),
#  Text(432.29357798165137, 291.2142857142858, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(455.045871559633, 291.2142857142858, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(489.17431192660547, 485.3571428571429, 'Age <= 75.5\nmse = 0.139\nsamples = 12\nvalue = 1.833'),
#  Text(477.79816513761466, 420.64285714285717, 'Income <= 107.0\nmse = 0.083\nsamples = 11\nvalue = 1.909'),
#  Text(466.42201834862385, 355.92857142857144, 'mse = 0.0\nsamples = 10\nvalue = 2.0'),
#  Text(489.17431192660547, 355.92857142857144, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(500.5504587155963, 420.64285714285717, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(546.0550458715596, 614.7857142857143, 'CompPrice <= 123.0\nmse = 0.49\nsamples = 10\nvalue = 0.9'),
#  Text(523.3027522935779, 550.0714285714287, 'Income <= 92.5\nmse = 0.222\nsamples = 3\nvalue = 1.667'),
#  Text(511.92660550458714, 485.3571428571429, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(534.6788990825688, 485.3571428571429, 'mse = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(568.8073394495412, 550.0714285714287, 'Price <= 136.5\nmse = 0.245\nsamples = 7\nvalue = 0.571'),
#  Text(557.4311926605504, 485.3571428571429, 'mse = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(580.183486238532, 485.3571428571429, 'mse = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(735.183486238532, 808.9285714285714, 'Population <= 20.5\nmse = 0.306\nsamples = 146\nvalue = 1.699'),
#  Text(712.4311926605504, 744.2142857142858, 'Price <= 85.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(701.0550458715596, 679.5, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(723.8073394495412, 679.5, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(757.9357798165137, 744.2142857142858, 'Population <= 508.5\nmse = 0.287\nsamples = 144\nvalue = 1.715'),
#  Text(746.5596330275229, 679.5, 'Advertising <= 1.5\nmse = 0.268\nsamples = 143\nvalue = 1.727'),
#  Text(668.3486238532109, 614.7857142857143, 'Price <= 109.5\nmse = 0.275\nsamples = 59\nvalue = 1.593'),
#  Text(614.3119266055046, 550.0714285714287, 'Population <= 397.5\nmse = 0.186\nsamples = 25\nvalue = 1.88'),
#  Text(602.9357798165137, 485.3571428571429, 'mse = 0.0\nsamples = 20\nvalue = 2.0'),
#  Text(625.6880733944954, 485.3571428571429, 'Age <= 64.5\nmse = 0.64\nsamples = 5\nvalue = 1.4'),
#  Text(614.3119266055046, 420.64285714285717, 'CompPrice <= 106.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(602.9357798165137, 355.92857142857144, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(625.6880733944954, 355.92857142857144, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(637.0642201834862, 420.64285714285717, 'mse = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(722.3853211009174, 550.0714285714287, 'CompPrice <= 136.5\nmse = 0.236\nsamples = 34\nvalue = 1.382'),
#  Text(682.5688073394494, 485.3571428571429, 'Education <= 11.5\nmse = 0.16\nsamples = 20\nvalue = 1.2'),
#  Text(659.8165137614678, 420.64285714285717, 'Price <= 126.0\nmse = 0.188\nsamples = 4\nvalue = 1.75'),
#  Text(648.440366972477, 355.92857142857144, 'mse = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(671.1926605504586, 355.92857142857144, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(705.3211009174312, 420.64285714285717, 'Income <= 99.5\nmse = 0.059\nsamples = 16\nvalue = 1.062'),
#  Text(693.9449541284404, 355.92857142857144, 'mse = 0.0\nsamples = 13\nvalue = 1.0'),
#  Text(716.697247706422, 355.92857142857144, 'Income <= 106.5\nmse = 0.222\nsamples = 3\nvalue = 1.333'),
#  Text(705.3211009174312, 291.2142857142858, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(728.0733944954128, 291.2142857142858, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(762.2018348623852, 485.3571428571429, 'Age <= 67.5\nmse = 0.23\nsamples = 14\nvalue = 1.643'),
#  Text(750.8256880733944, 420.64285714285717, 'Price <= 153.0\nmse = 0.149\nsamples = 11\nvalue = 1.818'),
#  Text(739.4495412844036, 355.92857142857144, 'mse = 0.0\nsamples = 8\nvalue = 2.0'),
#  Text(762.2018348623852, 355.92857142857144, 'Age <= 51.5\nmse = 0.222\nsamples = 3\nvalue = 1.333'),
#  Text(750.8256880733944, 291.2142857142858, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(773.5779816513761, 291.2142857142858, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(773.5779816513761, 420.64285714285717, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(824.7706422018348, 614.7857142857143, 'CompPrice <= 94.5\nmse = 0.242\nsamples = 84\nvalue = 1.821'),
#  Text(796.3302752293578, 550.0714285714287, 'Education <= 14.0\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(784.954128440367, 485.3571428571429, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(807.7064220183486, 485.3571428571429, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(853.2110091743119, 550.0714285714287, 'Population <= 32.0\nmse = 0.198\nsamples = 82\nvalue = 1.854'),
#  Text(830.4587155963302, 485.3571428571429, 'Income <= 73.5\nmse = 0.688\nsamples = 4\nvalue = 1.25'),
#  Text(819.0825688073394, 420.64285714285717, 'mse = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(841.834862385321, 420.64285714285717, 'Advertising <= 12.0\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(830.4587155963302, 355.92857142857144, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(853.2110091743119, 355.92857142857144, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(875.9633027522935, 485.3571428571429, 'Income <= 22.0\nmse = 0.153\nsamples = 78\nvalue = 1.885'),
#  Text(864.5871559633027, 420.64285714285717, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(887.3394495412844, 420.64285714285717, 'Population <= 499.5\nmse = 0.145\nsamples = 77\nvalue = 1.896'),
#  Text(875.9633027522935, 355.92857142857144, 'CompPrice <= 143.5\nmse = 0.136\nsamples = 76\nvalue = 1.908'),
#  Text(844.6788990825687, 291.2142857142858, 'CompPrice <= 100.0\nmse = 0.045\nsamples = 63\nvalue = 1.952'),
#  Text(816.2385321100917, 226.5000000000001, 'Income <= 70.0\nmse = 0.25\nsamples = 2\nvalue = 1.5'),
#  Text(804.8623853211009, 161.78571428571433, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(827.6146788990825, 161.78571428571433, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(873.1192660550458, 226.5000000000001, 'Population <= 495.0\nmse = 0.032\nsamples = 61\nvalue = 1.967'),
#  Text(850.3669724770642, 161.78571428571433, 'Advertising <= 18.5\nmse = 0.017\nsamples = 58\nvalue = 1.983'),
#  Text(838.9908256880733, 97.07142857142867, 'mse = 0.0\nsamples = 52\nvalue = 2.0'),
#  Text(861.743119266055, 97.07142857142867, 'Price <= 121.5\nmse = 0.139\nsamples = 6\nvalue = 1.833'),
#  Text(850.3669724770642, 32.35714285714289, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(873.1192660550458, 32.35714285714289, 'mse = 0.0\nsamples = 5\nvalue = 2.0'),
#  Text(895.8715596330275, 161.78571428571433, 'Income <= 43.0\nmse = 0.222\nsamples = 3\nvalue = 1.667'),
#  Text(884.4954128440367, 97.07142857142867, 'mse = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(907.2477064220183, 97.07142857142867, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(907.2477064220183, 291.2142857142858, 'Price <= 110.0\nmse = 0.521\nsamples = 13\nvalue = 1.692'),
#  Text(895.8715596330275, 226.5000000000001, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(918.6238532110091, 226.5000000000001, 'mse = 0.0\nsamples = 11\nvalue = 2.0'),
#  Text(898.7155963302752, 355.92857142857144, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(769.3119266055046, 679.5, 'mse = 0.0\nsamples = 1\nvalue = 0.0')]

# %%
y_predrk
# Out:
# array([1., 2., 0., 1., 2., 1., 2., 2., 2., 2., 2., 2., 1., 2., 2., 2., 1.,
#        1., 1., 2., 1., 2., 2., 1., 2., 1., 2., 2., 2., 2., 0., 2., 2., 1.,
#        2., 2., 0., 2., 2., 2., 2., 2., 1., 2., 1., 2., 1., 2., 2., 2., 1.,
#        2., 1., 1., 1., 0., 1., 2., 1., 0., 2., 2., 2., 2., 1., 2., 2., 2.,
#        1., 2., 2., 1., 1., 1., 1., 2., 1., 2., 1., 1., 2., 2., 2., 2., 1.,
#        2., 2., 2., 2., 2., 2., 2., 2., 1., 2., 2., 2., 1., 2., 2., 0., 2.,
#        2., 2., 2., 2., 2., 1., 2., 2., 1., 2., 1., 0., 1., 0., 2., 2., 2.,
#        1., 2., 0., 2., 2., 1., 1., 2., 2., 1., 1., 1., 1.])

# %%
accuracyrk =accuracy_score(y_test,y_predrk)
accuracyrk
# Out:
# 0.5984848484848485

# %%
count_misclassified =(y_test != y_predrk).sum()
count_misclassified
# Out:
# 53

# %%
print(classification_report(y_test,y_predrk))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.33      0.44        18
#            1       0.35      0.54      0.42        28
#            2       0.72      0.67      0.70        86
#
#     accuracy                           0.60       132
#    macro avg       0.58      0.51      0.52       132
# weighted avg       0.64      0.60      0.61       132
